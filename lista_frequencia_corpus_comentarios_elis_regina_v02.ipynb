# %%
import nltk, os, math, csv
from nltk.sem.logic import printtype
from nltk import tokenize
from nltk.util import ngrams

# %% [markdown]
# ## Contagem de palavras

# %%
# Abre o corpus específico
# O corpus específico pode estar dividido em vários arquivos TXTs. Em uma mesma pasta
# MAC
caminho_corpus_especifico = "/Users/bertolo/Dropbox/retorica_algoritimica/comentarios_elis_texto_unico.txt"
# Windows
# Corpus_especifico =  "C:\\Users\\ferna\\Dropbox\\retorica_algoritimica\\corpus_comentarios_elis"
# Caminho_corpus_especifico = "C:\\Users\\ferna\\OneDrive\\Escritorio\\corpus_especifico.txt"

# Abrindo o corpus geral
caminho_corpus_geral = "pt.txt"

# %%
# Conjunto de funções básicas / abre arquivo, faz o loglikelihood, calibra o corpus loglikelihood

def itera_ou_abre_arquivos(caminho_corpus):
    """
    Verifica se o caminho fornecidos leva a um txt, ou a diretório
    contendo arquivos txt. Retorna uma lista com os caminhos.

    Args:
        caminho_corpus(str): Caminho para um arquivo ou diretório específico.

    Returns:
        (str): O curpus é unido em uma única string
    """
    corpora = []
    # Se for um arquivo .txt, lê diretamente
    if caminho_corpus.endswith(".txt"):
        try:
            with open(caminho_corpus, "r", encoding="utf-8") as arquivo:
                corpora.append(arquivo.read())
        except OSError as e:
            print(f"Erro ao abrir o arquivo {caminho_corpus}: {e}")

    # Se for um diretório, lê todos os arquivos .txt dentro dele
    else:
        try:
            for nome_arquivo in os.listdir(caminho_corpus):
                if nome_arquivo.endswith(".txt"):
                    caminho_completo = os.path.join(caminho_corpus, nome_arquivo)
                    try:
                        with open(caminho_completo, "r", encoding="utf-8") as arquivo:
                            corpora.append(arquivo.read())
                    except OSError as e:
                        print(f"Erro ao abrir o arquivo {caminho_completo}: {e}")
        except OSError as e:
            print(f"Erro ao acessar o diretório {caminho_corpus}: {e}")
    corpora = " ".join(corpora)
    print(f"Nº Caracteres corpora: {caminho_corpus} - \n{len(corpora)}")
    return corpora

def string_to_freqdist(corpus):
    """ Transforma uma string em um objeto frqFist

    Args:
        corpus (str) - um objeto string

    Return:
        freqdist - FreqDist é uma subclasse de collections.Counter, ou seja, age como um contador de elementos.

        Métodos úteis:
        fdist.most_common(n): Retorna as n palavras mais frequentes.
        fdist.freq(palavra): Retorna a frequência relativa de uma palavra (proporção no total).
        fdist.plot(n): Plota um gráfico das n palavras mais frequentes.
        fdist.N(): Retorna o número total de palavras.
        fdist.keys(): Retorna as palavras únicas encontradas.

        Se a coleção de textos for muito grande, ele vai apresentar um resumo, como este:
        <FreqDist with 13280 samples and 67581 outcomes>
        Isso significa 13280 palavras únicas e 68581 palavras no total
     """

    # Cria o objeto token_espaco, da classe WhitespaveTokenizer,
    # Esse modulo tokenize, separa a string única em strings menores
    token_espaco = tokenize.WhitespaceTokenizer()
    corpus_tokenizado = token_espaco.tokenize(corpus)
    corpus_freqdist = nltk.FreqDist(word.lower() for word in corpus_tokenizado)

    return corpus_freqdist

def log_likelihood(oc, og, n, ng):
    """ Retorna um inteiro com o valor do loglikelihood

    Args:
        OC (int) - Ocorrencias no Corpus específico
        OG (int) - Ocorrencias no corpus Geral
        N  (int) - Tamanho do corpus especifico
        NG (int) - Tamanho do corpus geral

    Return - Int: resultado da verosemelhança

        Quanto maior o resultado retornado, menor a semelhança na distribuição das ocorrências.
        0, por exemplo, significaria uma distribuição exatamante igual.
        Esta função é importante para a função corpus_calibrado_log_likelihood()
    """

    taxa_ocorrencias = og / ng
    # OE - Ocerrencias esperadas com base no corpus geral
    oe = 1 if taxa_ocorrencias * n <= 0 else taxa_ocorrencias * n
    likelihood = 2 * (oc * math.log(oc / oe) + (n - oc) * (math.log((n - oc) / (n - oe))))

    return likelihood

def corpus_calibrado_log_likelihood(c_especifico_freqDist, c_geral_freqDist, limiar, stopwords=["a", "e", "i", "o", "u", ",", "?", "!"]):
    """ Entram dois corpora com freq e dist e sai um corpus com freq dist já calibrado

    Args
    # c_especifico_freqDist [freqDist] - Objeto contendo o Corpus específico
    # c_geral_freqDist [freqDist] - Objeto contendo uma amostra geral da língua
    # limiar [int] - Tolerância sobre o grau de semelhança. 0 = Mesma proporção. Bons valores variam de 1250 a 1750
    # stropwords [list] - Lista de palavras que deve ser excluidas do corpus de saída, independente do grau de varosssemelhança.

    Return - Um objeto freqdist

    A função compara o valor do loglikelihood, usando a função log_likelihood(), das ocorrencias de cada palavra do corpus específico no corpus geral.
    Se o valor estiver a baixo do limiar, a palavra é excluida da amostra.
    """

    c_especifico_calibrado = {}
    for palavra, freq in c_especifico_freqDist.items():
        if log_likelihood(freq, c_geral_freqDist[palavra], c_especifico_freqDist.N(),
                          c_geral_freqDist.N()) >= limiar and palavra not in stopwords:
            c_especifico_calibrado[palavra] = freq  # Corrigindo a atribuição ao dicionário

    c_especifico_calibrado = nltk.FreqDist(c_especifico_calibrado)
    return c_especifico_calibrado

# %%
# Função que egloba todas as funções da anterior. Entra uma string e retorna uma objeto freqDist (calibrado).
def lista_de_mais_frequentes_calibrada(caminho_corpus_especifico, caminho_corpus_geral, limiar, stopwords=["a", "e", "i", "o", "u", ",", "?", "!"]):
    """
        Abre duas str com o local dos corpora, sejam arquivos ou diretórios
        processa e devolve um arquivo FreqDist já com as palavras que estão acima do limiar retiradas.

    Args:
        caminho_corpus_especifico (str):
        caminho_corpus_geral (str):
        limiar (int):
        stopwords (list):

    return:
        (nltk.probability.FreqDist): Um objeto freqdist do corpus específico já calibrado na probabilidade.

        Métodos úteis:
        fdist.most_common(n): Retorna as n palavras mais frequentes.
        fdist.freq(palavra): Retorna a frequência relativa de uma palavra (proporção no total).
        fdist.plot(n): Plota um gráfico das n palavras mais frequentes.
        fdist.N(): Retorna o número total de palavras.
        fdist.keys(): Retorna as palavras únicas encontradas.

    A função compara o valor do loglikelihood, usando a função log_likelihood(), das ocorrencias de cada palavra do corpus específico no corpus geral.
    Se o valor estiver a baixo do limiar, a palavra é excluida da amostra.

     A função Depende de várias funções anteriores, como:
     itera_ou_abre_arquivos()
     string_to_freqdist()
     log_likelihood()
     corpus_calibrado_log_likelihood()
    """

    #
    # Entra o caminho dos corpus, específico e geral, e sai o corpus freqDist específico já calibrado

    # Entram dois caminhos de arquivos
    # Sai um objeto nltk.probability.FreqDist

    # strings
    corpus_especifico = itera_ou_abre_arquivos(caminho_corpus_especifico)
    corpus_geral = itera_ou_abre_arquivos(caminho_corpus_geral)

    # String freqdist
    c_especifico_tokenizado = string_to_freqdist(corpus_especifico)
    c_geral_tokenizado = string_to_freqdist(corpus_geral)

    # Chama a função corpus freqdist calibrado
    corpus_calibrado = corpus_calibrado_log_likelihood(c_especifico_tokenizado, c_geral_tokenizado, limiar, stopwords)
    return corpus_calibrado

# %%
# Entra um corpus freqDist e salva um .cvs com os x primeiros resultados
def salva_csv_de_corpus_freq_dist(corpus_freqDist, entradas=10, nome_do_arquivo="corpus.csv", delimitador=";"):
    """ Transforma um objeto freqdist em um arquivo csv com uma lista dos N mais frequentes

        args:
            corpus_freqDist(freqdist): freqDist é uma subclasse de collections.Counter, ou seja, age como um contador de elementos.
            entradas(int): Número de linhas que o csv vai ter
            nome_do_arquivo(str): É bom que ele termine com a extenção csv
            delimitador(str): O Caractere que vai ser usado para separar os campos

        return:
            Salva um arquivo .csv na mesma pasta do script

        Dica: Caso se queira usar um "tab" como delimitador, o caractere é o "\t"

            """
    # Cabeçalho do csv
    dados = [["N","Palavra", "Frequência"]]
    counter = 1

    for key, freq in corpus_freqDist.most_common(entradas):
        linha = [counter, key, freq]
        counter += 1
        dados.append(linha)
    # Criando e salvando o arquivo CSV
    with open(nome_do_arquivo, "w", newline="", encoding="utf-8") as arquivo_csv:
        escritor = csv.writer(arquivo_csv, delimiter=delimitador, quotechar='"', quoting=csv.QUOTE_MINIMAL)
        escritor.writerows(dados)

    print("CSV salvo com sucesso!")

# %%
# Salva os csv dos corpora: especifico, geral e específico filtrado 

# ESPECÍFICO
# 1 - Abre o corpus e transforma em (str)
corpus_especifico = itera_ou_abre_arquivos(caminho_corpus_especifico)
# 2 - Transfor a string em um objeto freqDist
corpus_especifico_freqDist = string_to_freqdist(corpus_especifico)
# 3 - Salva os 16 termos mais frequentes
salva_csv_de_corpus_freq_dist(corpus_especifico_freqDist, 16, "corpus_especifico_v02.csv", "\t")

# GERAL
# 1 - Abre o corpus e transforma em (str)
corpus_geral = itera_ou_abre_arquivos(caminho_corpus_geral)
# 2 - Transfor a string em um objeto freqDist
corpus_geral_freqDist = string_to_freqdist(corpus_geral)
# 3 - Salva os 16 termos mais frequentes
salva_csv_de_corpus_freq_dist(corpus_geral_freqDist, 16, "copacabana_v02.csv", "\t")

# ESPECÍCO FILTRADO
# 1
corpus_geral_filtrado = lista_de_mais_frequentes_calibrada(caminho_corpus_especifico,caminho_corpus_geral,900)
salva_csv_de_corpus_freq_dist(corpus_geral_filtrado,16,"copacabana_filtrado.csv", "\t")
# Out:
# Nº Caracteres corpora: /Users/bertolo/Dropbox/retorica_algoritimica/comentarios_elis_texto_unico.txt -
# 411650
# CSV salvo com sucesso!
# Nº Caracteres corpora: pt.txt -
# 17034654
# CSV salvo com sucesso!
# Nº Caracteres corpora: /Users/bertolo/Dropbox/retorica_algoritimica/comentarios_elis_texto_unico.txt -
# 411650
# Nº Caracteres corpora: pt.txt -
# 17034654
# CSV salvo com sucesso!

# %%
# Imprime os temos mais comuns em um corpus calibrados


string = itera_ou_abre_arquivos(caminho_corpus_especifico)
fq = lista_de_mais_frequentes_calibrada(caminho_corpus_especifico,caminho_corpus_geral,1400)
fq.most_common(20)
# Out:
# Nº Caracteres corpora: /Users/bertolo/Dropbox/retorica_algoritimica/comentarios_elis_texto_unico.txt -
# 411650
# Nº Caracteres corpora: /Users/bertolo/Dropbox/retorica_algoritimica/comentarios_elis_texto_unico.txt -
# 411650
# Nº Caracteres corpora: pt.txt -
# 17034654
# [('parabéns', 779),
#  ('propaganda', 610),
#  ('comercial', 574),
#  ('elis', 465),
#  ('❤', 364),
#  ('lindo', 329),
#  ('volkswagen', 267),
#  ('linda', 251),
#  ('vw', 248),
#  ('emocionante', 208),
#  ('ditadura', 144),
#  ('regina', 139),
#  ('você', 26)]

# %% [markdown]
# ## Concordanciadores

# %%
# Concordanciador de uma palavra chave com o corpus em um único texto

# Arquivo para string
corpus_especifico = itera_ou_abre_arquivos(caminho_corpus_especifico)

# entra uma string tokenizada por palavras
# Cria o token
token_espaco = tokenize.WhitespaceTokenizer()
# Tokeniza o texto
corpus_tokenizado = token_espaco.tokenize(corpus_especifico)

corpus_textizado = nltk.Text(corpus_tokenizado)

# Gerar a lista de concordância para a palavra "whale"
corpus_textizado.concordance("elis", width=200, lines=100)
# Out:
# Nº Caracteres corpora: /Users/bertolo/Dropbox/retorica_algoritimica/comentarios_elis_texto_unico.txt -
# 411650
# Displaying 100 of 465 matches:
#  Não vi nada demais. Talvez pq seja feito com base em um certo culto que eu nunca entendi bem pq, Elis Regina (mediazinha) cantando a música mais chinfrim do Belchior 🥰☺️ Vim do twitter só pra conferi
# ra Encantador, trabalho belissimo. Parabens a todos envolvidos. 🎉❤ Genial!! Tive Fuscas e Kombis. Elis em IA com Maria Rita ❤❤❤❤ 🌾🍂☕🌾🍃🦋 Muito boa..... gostei demais Uau!!!! 🤩🤩🤩🤩👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼🥹🥹🥹🥹🥹🥹🥹🥲🥲🥲❤
# ís e nossa história ❤ Eu não gostei. Eu Asmei!!!!!! 😍😍😍 Q bizarro... Essa cara computadorizada da elis regina pra vender carro..🤦🏿‍♀️🤦🏿‍♀️🤦🏿‍♀️ Uau, que comercial lindo! Foi de uma delicadeza trazer c
# que comercial lindo! Foi de uma delicadeza trazer cenas cotidianas da vida, a música escolhida, a Elis e Maria Rita, sensacional! Parabéns, de arrepiar!! 👏🏻 Volks, mais bonita que a Elis é a nova Komb
#  escolhida, a Elis e Maria Rita, sensacional! Parabéns, de arrepiar!! 👏🏻 Volks, mais bonita que a Elis é a nova Kombi. Incrível. :D Que propaganda lindaaaa Parabéns, linda homenagem, que falta nos faz
# ilhosa a propaganda! Ridículo e constrangedor pra qualquer um que tenha no mínimo dois neurônios. Elis Regina jamais faria tal comercial! Por isso cuidado meu bem Há perigo na esquina Eles venceram E
# ela nunca iria escolher ser vinculada a uma grande empresa que um dia patrocinou a ditadura que a elis tanto abominava. Triste. Lindo! 💙 Até quem fim volks, um comercial sem lacração, que remete a lem
# rasilia Amarela dos Mamonas Assassinas 🙌🙌🙌😎😎😎, parabéns pelo belo comercial e a ótima homenagem a Elis Regina e pela escolha da música de Belchior . Que coisa mais linda...❤ Chorei! Impossível não se
# uilo que DEUS levou não faz mais parte desse mundo só aguarda o juízo Arrebatador 😢 ARREPIEI!!!!. ELIS E MARIA RITA. ❤ "Viver é melhor do que sonhar" Pelo jeito, com a inteligência artificial, ninguém
# só é bem irônico ser da Volkswagen, mesma empresa que na época apoiou a ditadutra militar (a qual Elis Regina fazia oposição) e entregava opositores aos militares, mesmo sabendo que seriam detidos e t
# i uma Brasília amarela... Cara que propaganda linda sem Mimi, muito raiz parabéns Volkswagen!!! A Elis Regina se retorcendo no caixão vendo sua filha fazer propaganda da empresa que apoiou governos qu
# paganda. A ética deveria ser levada em consideração na produção de qualquer comercial. Certamente Elis nunca faria essa propaganda, já que esta empresa apoiou a a ditadura militar.😢 Polêmico e emocion
# sformar até mesmo uma música comunista em mercadoria, parabéns wolkvagen, a critica de Belchior e Elis Regina estava certa, até porque apesar de toda militância contra a ditadura, no final tudo virou
# nante, nostálgico... parabéns Volkswagen! ❤ Estou chorando, é muita emoção Amei demais! Sou fã de Elis e da filha. Ambas são maravilhosas❤ Que show de propaganda.... O melhor comercial em muitos anos,
# bi, não admiravam a passagem dos santanas...ou aprendeu a dirigir em um fusca. Parabéns volks❤❤❤❤ Elis Regina merece todas as homenagens que puderem ser feitas a ela e tenho certeza que foi um present
# mpo que não se vê uma propaganda tão bacana. Me lembrou os comerciais dos anos 80. Adorei rever a Elis e a lembrança do Belchior. Maria Rita canta muito. Parabéns aos criadores. Chorei muito, meu jesu
# lywood que não tínhamos uma propaganda a altura. Parece trailer de filme! Me emocionei demais!!!! Elis Regina e uma kombi Minha mae é inspirada nela Hj uma cantora e músico terapeuta leila rosa Uau...
# 🥰🥰 Que espetáculo!! Sem palavras com a brilhante Maria Rita e um monstro sagrado q foi a incrível Elis Regina ... Parabéns a Volkswagen pela homenagem 👏👏👏 Caramba já pode voltar a respirar? Mano que l
# ela nunca iria escolher ser vinculada a uma grande empresa que um dia patrocinou a ditadura que a elis tanto abominava. Triste. VW conseguiu reinventar a propaganda comercial😮 Tadinho do Belchior, não
# icais??? A música não tem nada haver com a homenagem... Nossa, que peça EMOCIONANTE! Em lágrimas. Elis Regina foi consultada, para ter sua imagem vinculada a uma empresa que apoiou a ditadura militar,
# tra questão é ética, será que é ético colocar artistas que já morreram, em comerciais? Será que a Elis gostaria de ter sua imagem vinculada a VW? Acredito que se estivesse viva até faria o comercial p
# massa a inteligência artificial o que ela é capaz Kkkk gzus os cara q apoavam a ditadura usando a Elis Regina, parece até piada com a nossa cara e dos m0rtos e t0rtur4dos. O povo acha q memoria histór
# . Mas gostei da mão no vidro embaçado no 1:36 😉. Deep fake nao convence ha algo de mecanico nessa Elis Regina. Uma propaganda que me levou no passado, me fez pensar no futuro me fez sentir feliz com o
#  no futuro me fez sentir feliz com o hoje. Ai gente ❤ eu vou comprar ❤ em nome de Jesus ❤❤❤ beijo Elis ❤❤❤❤ Anos 70!!!!! Inesquecíveis!!!! Para mim e para quem os viveram. Essa campanha é linda, emoci
#  más agora... caraiii!! vcs pegaram pesado...👏👏👏😭 Sensacional A campanha mais linda que eu já vi. Elis estava linda e Maria Rita formidável. Lindo lindo Mais que uma propaganda…. Mexeu com as lembranç
# to comentário da eaquerdalha criticando por ser um comercial e que seria muito "capitalista" para Elis Regina mas esquecem de enxergar a história do próprio Brasil contado em carros. Emocionante nunca
#  passado e nos trazendo alguns dos carros que inovam nosso dia a dia tudo num pacote só. "Saudosa Elis Regina" "parabens Maria Rita" "parabens volkswagen" É o fim do mundo mesmo, é um desrespeito nem
#  desrespeito nem quem já se foi. de qual parte o ''descanse em paz'' a volkswagen não entendeu? a Elis se revirando no túmulo, ja nem descansa mais em paz! Logo a maior imagem do Brasil contra a ditad
# u um tiro na cara do sistema lacrador ))) englobando todos os filhos de George Soros tomara que a elis regina arranque um bom dinheiro de voces euheuh Foi um comercial muito lindo… eu até chorei Melho
# uito maneiro. A parte do mapa do carona, mt meu avô viajando.... que saudade! Chorei muito. Amo a Elis pra sempre e Rita tbm Comecei minha vida de motorista dirigindo um Fusca 1500 1973 do meu pai boa
#  GM podia fazer um lance assim com o OPALA.. @Volkswagen do Brasil, quando vão relançar o VW SP?❤ Elis eu nao tenho certeza, ma Belchior jamais aprovaria o uso do seu rosto e de sua música nessa propa
# alismo tardio. Parabéns, VW! Música horrível. Que LINDO!!!! Maaano....a VW simplesmente colocou a Elis Regina dirigindo a Corujinha....e a Maria Ritaa ID BUS .melhor comercial do ano Que coisa mais li
# , merecem ganhar todos os prêmios da imprensa brasileira, perfeito! Incrível. Parabéns Meu nome é Elis Regina em homenagem a Grande Elis Regina... parabéns só pessoal de marketing da Volkswagen ❤ é de
# da imprensa brasileira, perfeito! Incrível. Parabéns Meu nome é Elis Regina em homenagem a Grande Elis Regina... parabéns só pessoal de marketing da Volkswagen ❤ é de arrepiar Só mesmo a paixão e a cr
# itar no Brasil e por prestar uma belíssima homenagem a duas paixões brasileiras: MPB cantada pela Elis Regina e Maria Rita e pelos carros que marcaram, marcam e marcarão inúmeras legiões de fãs! Propa
# is velhos prós mais novos. Eu posteriormente tive um GOl G3 ano 2000. Segundo é ver através de IA Elis Regina e sua filha Maria Rita juntas em um comercial. Parabéns a Volkswagen e principalmente a to
#  emocionante Kind of creepy ❤adorei!!!! Nojo. Essa empresa apoiou a ditadura, msma DITADURA que a Elis lutou contra!! #NOJO Obrigado por ésta propaganda Coisa mais linda!!! Ahhhh coisa mais linda! Emo
#  à almap bbdo e à Volkswagen ❤ A lacração tá criticando a VW por apoiar a Intervenção Militar e a Elis ser contra, mas vivem falando em retratação, garanto que não poderia haver retratação mais linda,
# rtuno. Parabéns aos envolvidos 👏👏👏👏 Linda demais Simplesmente emocionante. Chorei na mesma hora q Elis apareceu. Que propaganda top! Melhor propaganda..da década..me emocionou muito ❤❤❤❤ Dois momentos
# , eu com 10 anos, em 1982, dentro de um fusquinha, com meus pais, ouvindo no rádio que o corpo de Elis Regina se encontrava, naquele momento no IML; outro, eu com 51, em 2023,vendo um comercial que é
# rar por ter financiado a DIATADURA que vcs financiaram no brae que perseguiu ela e tantos outros. Elis e Belchior devem estar se revirando no tumulo neste momento, uma música que combatia a ditadura v
# minha infância toda dentro da Kombi amarela do meu pai! Parabéns Wv,parabéns Maria Rita 2:00 viva Elis Regina e Belchior! Lindo demais! Nunca havia chorado vendo comercial.❤❤❤❤😢😢 Quem me dera reencont
# c ter prazer em assistir um comercial Q medo Se nos emociona assistir, imagina o que a família da Elis sente! Caramba! Que coisa mais linda! Impecável! Adorei a referência do Belchior❤❤❤❤❤. Olha, aume
# u avô; Parati do meu pai; Brasília amarela dos mamonas; Kombi do meu padrinho; Belchior na voz de Elis Regina e Maria Rita e GTI azul Mônaco. Covardes kkkkk A Kombi antiga é tão linda né, lindo comerc
# itadura militar mandou um salve 💩💩 O conar ta querendo proibir emocionante. O dueto inédito entre Elis Regina e Maria Rita para um comercial em celebração aos 70 anos da marca Volkswagen causou uma on
#  vim por causa da Lorelay! É lindo, mas quem conhece a letra e história por trás sabe, que jamais Elis cantaria esta canção com um sorriso no rosto. Mas tirando esse ponto, o comercial é lindo, emocio
# rível essa propaganda Publicidade ainda respira, parabéns! Showwww Gostei 👏🏽👏🏽👏🏽👏🏽👏🏽 Qq coisa que Elis esteja é pura obra de arte. Parabéns!!! Só dou os parabéns para a Volkswagen..... excelente traba
#  admiradores da marca, continua sendo atualidade). Que coisa linda!!! Nostalgia pura! Maria Rita, Elis e Volks, tudo de mais lindo reunido! Eu ainda posso dizer que curto muito as relíquias da Volks.
# .. Parabéns a todos envolvidos neste comercial. Para mim é o melhor que já vi em toda minha vida. Elis Regina e Maria Rita juntas. ❤❤❤❤❤ gentemmmm essa gordinha ai é a maria rita????? jesus....porque
# s, a música, a homenagem ao Belchior...Pqp, Parabéns pela campanha, parabéns pelos 70 anos!!! Amo Elis ,amo Maria Rita @@@❤❤❤❤❤❤ O melhor comercial do ano e tem gente entrando na justiça para retirar.
# da propaganda vw Brasil agradece ❤ Uma Kombi com preço de BMW kkk de popular ficou no passado ... Elis Regina é atemporal 😭♥️💛💚💜 Volkswagen, parabéns! 😍❤ As lágrimas teimam em cair. Saudade Gatú ❤ Emo
# completa sem a narração? That's one uncanny valley. Que trabalho maravilhoso!!! Emocionante ver a Elis com a Maria !!!! VW❤ https://youtu.be/cwP-llzzgvE Terminei de assistir o vídeo com os olhos cheio
# .. Absurdamente incrível ❤ Eu ameiiiiiii CONAR lixo!!! Eita marinha… Muito lindo mesmo amei Cara, Elis sempre emociona, a letra foi de uma época marcante ,ela pode dizer muitas coisas Eu amei com toda
# pados com o importantíssimo trabalho deles. Fantástico,chegou a dar uma certa emoção. eternamente Elis 👏🏾👏🏾👏🏾👏🏾 Não amo carros, mas o clipe é lindo, sensacional. Compre Chevrolet 70 vezes melhor. arre
# ntos em família dentro de um Fusca, uma Brasília, uma Kombi e um Gol quadrado Isso mostra o qto a Elis é IMORTAL INESQUECÍVEL INIGUALÁVEL. Maria Rita herdou esse talento da mãe Chorei Sensacional Viva
# Rita herdou esse talento da mãe Chorei Sensacional Viva a Volkswagen que apoiou a ditadura!!! E a Elis Regina que revira no túmulo com essa propaganda!!! Obrigada por não vir com lacração! Eu praticam
# , chorando sem parar agora... Que emocionante, parabens aos envolvidos. Legal né Meu Deus! 🥹 esse Elis Regina canta muito hem, ficou ótima, agora só falta Raulzito, Renato Russo, Rita Lee juntos, quem
# ais lindos e que vale a pena de ser visto,emocionante demais ,sem palavras Linda homenagem a VW , Elis Regina, Maria Rita, Belchior e acima de tudo ao povo Brasileiro que viveu essa história ❤ Emocion
# r me contratado pra fazer o lance da IA ai kkkkkk brinks! Impossível não se emocionar!!! Quem ama Elis e Maria Rita!! Caramba!!!!! não vejo a hora de ver o video do gaveta fazendo review dessa propaga
#  políticos para serem torturados. Procede? Sem falar que esse comercial é de grande ironia pois a Elis Regina era opositora à ditadura Que propaganda mais linda, emocionante 💖 Sem palavras para esse c
# m São Vicente, eu tinha 19 anos e lembro perfeitamente do choque que minha mãe levou quando viu a Elis no jornal A Folha de São Paulo dentro do caixão com a bandeira do Brasil, ela comprou o jornal e
# . Um comercial como este é simplesmente INCRÍVEL!!! Mostra amores eternos do Brasil como a eterna Elis e a Kombi Volkswagen, ameeeeiii! Um toque de alta inteligência com bom gosto. Digo mesmo! Se tive
#  Digo mesmo! Se tivesse como,eu compraria uma Kombi só por este comercial. P A R A B E N S !!!! A Elis Regina escolheu cantar numa fábrica para os operários, ao invés do Rio Centro no dia do trabalhad
# elão. Derretendo de emoção aqui! Saber que a IA não serve apenas para o mal, para alimentar ódio! Elis jamais aceitaria isso em vida. Desrespeitoso e antiético. Que campanha sensível e doce !!! Maravi
# nda tão Linda ❤❤❤❤ Meu Deus que sensacional 🎉😢 Que demais! Que sensibilidade 😻😻 Hilario musica de Elis contra ditadura militar na wolks que sempre apoia ditadura militar,😂😂😂😂, mas a combi equetidinha
#  sempre apoia ditadura militar,😂😂😂😂, mas a combi equetidinha do Brasil ❤❤❤ A Volkswagen colocar a Elis na propaganda chega a ser estapafúrdio. Porque nao aproveitamos a deixa pra falar sobre as acoes
# indoooooooooooooooooooooooooooooooooo Eu toda arrepiada Belissima propaganda ! Mano Mano filha da elis tem a alma da mãe na voz se loko Fantástica e emocionante, chorei de emoção, os últimos 70 anos a
# endeu na Dr. Arnaldo ficou pasmo de ver que a peça era original depois de 22 anos! Espetacular!!! Elis e Belchior! Caiu até um "cisco" no meu olho... propaganda de uma empresa que apoiou a ditadura, u
# om IA... Linda homenagem❤ Vi 10x arrepiei 11x Que propaganda lindaaaa ❤ Bela homenagem, à querida Elis Regina ! Parabéns Volkswagem, lindo comecial. Linda propaganda!!! parabéns VW!!! Nunca fui fã de
# menagem...agora vivemos numa geração perdida, já estao cogitando de processo pela IA utilizada da Elis Regina na propagando...por favor né gente!!. Quando vi a reportagem maldosa achava que tinham uti
# e essa ideia é um gênio. Arrepiado! Arrepio que fala!!!!! ❤️❤️ Amei, lindo demais! 😍 Parabéns 👏 a elis jamais cantaria essa canção dessa forma, muito menos pra volkswagem Linda propaganda... Preciso m
# eria ser outra trilha comum a Maria Rita e Elis, envolvendo a Volks. Mas essa não, essa na voz de Elis é um símbolo nacional. Que coisa lindaaaa Volks ❤ Até que enfim uma propaganda decente e que vale
# ... É se arrepiar!!! Parabéns aos criadores. Não sabia que a outra mulher do comercial é filha da Elis e não conhecia a música, mas é um bom comercial Parabéns pelo video institucional, me arrepiei e
#  ❤ Muiiiiiiiiiiiiiiiiiiito bom comercial.... Parabéns pelo vídeo maravilhoso! Emocionante demais! Elis Regina e Maria Rita, uma música que é inesquecível! Kombi, Fusca, Brasília, e tantos outros carro
# os parabéns voltei ao passado com muita saudade. Me acabando de chorar aqui. Saudosa "pimentinha" Elis sempre no nosso coração.♥️🌶️ Que maravilhoso assistir um comercial que não seja apelativo sexual.
# embranças especiais de quem amamos e quem já partiu. Eu tô chorando, pode isso ?? OMG 😲 😲 😲 😲 😲 😲 Elis se revirou no túmulo linda homenagem Fiquei extremamente emocionada! 🥺🥺🥺 muito emocionante o vide
# r carro. Que b0st@! Vale tudo por dinheiro Que propaganda mais linda! Além dessa bela homenagem a Elis Regina, lembrei meu pai que infelizmente não está mais entre nós…costumávamos acampar, e meu pai
# rtam as coisas que são relevantes. Parabéns pelo aniversário 🎂🎁 d 70 , Fora a homenagem da rainha Elis Regina com a filha 🙏. Quem nunca teve um Fusca Brasília Kombi gol kkkk Volkswagen é Brasil Incrív
# o sentimental ! VW ad eternum ! Quantas memórias meu Deus! Me arrepiei aqui e com essa música com Elis e com Maria Rita acabou comigo. Emocionadíssima! Viver é melhor que sonhar !!! que saudade da Eli
# i em um comercial da VW foi o da despedida da Kombi com a locução da Maria Alice Vergueiro. Ver a Elis num vídeo junto com a Maria Rita mexeu demais aqui. Parabéns equipe VW pela produção, sensacional
# er tudo o que senti ao ver esse vídeo!!!! Muito obrigada!!!! Genial! Emocionante para quem admira Elis e Maria Rita. As propagandas são para vender, mas antigamente tinha um lado muito humano nas prop
# ulação tecnológica difundindo um significado oposto aos que significavam em sua gênese. A cantora Elis e essa obra de Belchior outro grande músico, compositor e letrista em sua voz são associados ao i
# U L A R. Que baita mexida nos nossos sentimentos! Ufa! Uaaauuu ....😁👏👏👏👏 ...que incrível ...botar Elis Regina e sua filha Maria Rita juntas ....muito bom , parabéns para quem idealizou essa propaganda
# é o contrário do que a marca quer passar. quem não gostou porque é ruim de espírito dáni- se se a elis nao ia gosta, você sabe ? as vezes ela ia gostar e ri a filha dela deve ter amado fazer ficou lin
# ve nas nossas historias ), o link entre o que foi a VW no passado e o que já é o futuro, e quando Elis aparece ... MEU DEUS !!!! Galerinha dos anos 70/80 num guenta não. Parabéns VW, deu até vontade d
#  coisa linda, meu Deus! Melhor comercial que já vi na vida!!! É uma bela homenagem a inesquecível Elis É esquisito. Estão mexendo com fantasmas. Top o comercial sem lacrar.... Acho que a VW não entend
# 👏🏻👏🏻👏🏻😀 Bizarro Volkswagen sua linda, que comercial perfeito. É impossível não se emocionar com a Elis e a Maria Rita cantando juntas, e as imagens de nostalgia dos carros que fizeram a história da ma
# a aos idealizadores dessa obra de arte!!!Viva o passado!Viva o presente!!!👏🏻👏🏻👏🏻 👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻 Elis Regina igual boneco de vídeo game O comercial até que é bem feito, mas eu não senti absolutamente
# nos 80 Maravilhoso e arrepiante! Parabéns! O novo sempre vem! 🤗 Que beldade! Eu achei a imagem da Elis muito artificial, o olhar é inexpressivo. Parece um robô cantando. A ideia do comercial é genial,
# ar, e convencer o cliente. SIMPLES!! Que comercial lindo! Fiquei emocionado em ver a nossa eterna Elis "cantando" com a sua filha. Reportagem especi Que comercial lindo ❤️ 👏👏👏👏 Direito autoral e direi
# inados (imagem e voz por IA) para atacar a memória (dir. personalidade) que só à pessoa pertence. Elis cantou para operários da Volks, não para vender carros. Padeiro faz pão delicioso para vender, nã
# e significados, referências. Perfeita! Parabens...a anos nao via um comercial lindo na estetica e Elis enternizada. Parabens a familia que autorizou AI ... Sensacional! Só faltou o novo e-Bettle, noss
# onito. E emocionante. Impossível não chorar. A melhor campanha que já assisti! Isso é um CRIME!!! Elis NUNCA Faria essa propaganda pra uma empresa que apoiou até o talo a Ditadura e os militares!!!! P
# com esse trabalho!!!! Entrou para história Achei o comercial lindo, mas, preocupante. Colocaram a Elis dentro de uma Kombi...Isso nunca aconteceu. Daqui a pouco estarão produzindo falas sendo oralizad
# . Parabéns pela homenagem... muita linda ..inovadora ....rs❤😊 Linda propaganda Muito identifica a elis regina foi feita a propaganda atraves da inteligência artificial quando a elis regina morreu eu t
# Muito identifica a elis regina foi feita a propaganda atraves da inteligência artificial quando a elis regina morreu eu tava nascendo eu nasci em agosto de 1982 e não lembro o dia e mês que ela morreu
# da com ela quando jovem Espetáculo 👏👏👏 Rapaz, chorando aqui, além de ser incrível ver a grandiosa Elis Regina cantando ao lado de sua filha Maria Rita, quantas lembranças boas me veio, minha infância
# m gostinho de quero mais.Parabéns Artisticamente é uma belissima composição, agora criticamente a Elis era completamente contra o Regime Ditatorial Militar/Empresarial o qual a Volks forneceu amplo ap
# ão conhecem ou só sabem dessa música, possam ouvir o repertório maravilhoso dessa estrela chamada Elis Regina. Ficou perfeito, ainda apareceu o Belchior ❤ Arrepiada aqui! A empresa que financiou e apo
#  Arrepiada aqui! A empresa que financiou e apoiou a ditadura se utilizando da imagem e da obra de Elis Regina é uma ação aviltante à finada cantora, uma afronta à sua memória. #DitaduraNuncaMais Que p

# %%
# Concordanciador de uma única palavra chave com o corpus dividido em uma lista de strings

pasta_corpus = "corpus_comentarios_elis/"

# Para cada arquivo dentro de uma pasta
for arquivo in os.listdir(pasta_corpus):
    # Verifica se o arquivo termina com txt
    if arquivo.endswith(".txt"):
        caminho_arquivo = os.path.join(pasta_corpus, arquivo)

        # Abre o arquivo e tranforma o texto em uma string
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            texto = f.read().strip()  # Remove espaços extras

        # Tokeniza a sentença
        token_espaco = tokenize.WhitespaceTokenizer()
        corpus_token = token_espaco.tokenize(texto)

        # Cria o objeto Text do NLTK
        corpus_text = nltk.Text(corpus_token)

        # Exibe concordância se a palavra alvo existir
        palavra_alvo = "Elis"
        if palavra_alvo in corpus_token:
            corpus_text.concordance(palavra_alvo, width=100)
# Out:
# Displaying 1 of 1 matches:
#  em um certo culto que eu nunca entendi bem pq, Elis Regina (mediazinha) cantando a música mais chin
# Displaying 1 of 1 matches:
#                  Genial!! Tive Fuscas e Kombis. Elis em IA com Maria Rita ❤❤❤❤
# Displaying 1 of 1 matches:
# cenas cotidianas da vida, a música escolhida, a Elis e Maria Rita, sensacional!
# Displaying 1 of 1 matches:
#                        Volks, mais bonita que a Elis é a nova Kombi. Incrível. :D
# Displaying 1 of 1 matches:
#                                                 Elis Regina jamais faria tal comercial!
# Displaying 1 of 1 matches:
# abéns pelo belo comercial e a ótima homenagem a Elis Regina e pela escolha da música de Belchior .
# Displaying 1 of 1 matches:
# que na época apoiou a ditadutra militar (a qual Elis Regina fazia oposição) e entregava opositores a
# Displaying 1 of 1 matches:
#                                               A Elis Regina se retorcendo no caixão vendo sua filha
# Displaying 1 of 1 matches:
# o na produção de qualquer comercial. Certamente Elis nunca faria essa propaganda, já que esta empres
# Displaying 1 of 1 matches:
# ia, parabéns wolkvagen, a critica de Belchior e Elis Regina estava certa, até porque apesar de toda
# Displaying 1 of 1 matches:
#                          Amei demais! Sou fã de Elis e da filha. Ambas são maravilhosas❤
# Displaying 1 of 1 matches:
#                                                 Elis Regina merece todas as homenagens que puderem s
# Displaying 1 of 1 matches:
# mbrou os comerciais dos anos 80. Adorei rever a Elis e a lembrança do Belchior. Maria Rita canta mui
# Displaying 1 of 1 matches:
#                                                 Elis Regina e uma kombi Minha mae é inspirada nela H
# Displaying 1 of 1 matches:
# aria Rita e um monstro sagrado q foi a incrível Elis Regina ... Parabéns a Volkswagen pela homenagem
# Displaying 1 of 1 matches:
#                                                 Elis Regina foi consultada, para ter sua imagem vinc
# Displaying 1 of 1 matches:
# stas que já morreram, em comerciais? Será que a Elis gostaria de ter sua imagem vinculada a VW? Acre
# Displaying 1 of 1 matches:
# Kkkk gzus os cara q apoavam a ditadura usando a Elis Regina, parece até piada com a nossa cara e dos
# Displaying 1 of 1 matches:
# eep fake nao convence ha algo de mecanico nessa Elis Regina.
# Displaying 1 of 1 matches:
# e ❤ eu vou comprar ❤ em nome de Jesus ❤❤❤ beijo Elis ❤❤❤❤
# Displaying 1 of 1 matches:
#             A campanha mais linda que eu já vi. Elis estava linda e Maria Rita formidável. Lindo lin
# Displaying 1 of 1 matches:
#  comercial e que seria muito "capitalista" para Elis Regina mas esquecem de enxergar a história do p
# Displaying 1 of 1 matches:
# am nosso dia a dia tudo num pacote só. "Saudosa Elis Regina" "parabens Maria Rita" "parabens volkswa
# Displaying 1 of 1 matches:
#                                               a Elis se revirando no túmulo, ja nem descansa mais em
# Displaying 1 of 1 matches:
#                             Chorei muito. Amo a Elis pra sempre e Rita tbm
# Displaying 1 of 1 matches:
#                                                 Elis eu nao tenho certeza, ma Belchior jamais aprova
# Displaying 1 of 1 matches:
#           Maaano....a VW simplesmente colocou a Elis Regina dirigindo a Corujinha....e a Maria Ritaa
# Displaying 2 of 2 matches:
#                                      Meu nome é Elis Regina em homenagem a Grande Elis Regina... par
#    Meu nome é Elis Regina em homenagem a Grande Elis Regina... parabéns só pessoal de marketing da V
# Displaying 1 of 1 matches:
# em a duas paixões brasileiras: MPB cantada pela Elis Regina e Maria Rita e pelos carros que marcaram
# Displaying 1 of 1 matches:
# um GOl G3 ano 2000. Segundo é ver através de IA Elis Regina e sua filha Maria Rita juntas em um come
# Displaying 1 of 1 matches:
#  empresa apoiou a ditadura, msma DITADURA que a Elis lutou contra!! #NOJO
# Displaying 1 of 1 matches:
# cando a VW por apoiar a Intervenção Militar e a Elis ser contra, mas vivem falando em retratação, ga
# Displaying 1 of 1 matches:
# implesmente emocionante. Chorei na mesma hora q Elis apareceu. Que propaganda top!
# Displaying 1 of 1 matches:
#  com meus pais, ouvindo no rádio que o corpo de Elis Regina se encontrava, naquele momento no IML; o
# Displaying 1 of 1 matches:
#                                                 Elis e Belchior devem estar se revirando no tumulo n
# Displaying 1 of 1 matches:
#  pai! Parabéns Wv,parabéns Maria Rita 2:00 viva Elis Regina e Belchior! Lindo demais!
# Displaying 1 of 1 matches:
# s emociona assistir, imagina o que a família da Elis sente!
# Displaying 1 of 1 matches:
# onas; Kombi do meu padrinho; Belchior na voz de Elis Regina e Maria Rita e GTI azul Mônaco. Covardes
# Displaying 1 of 1 matches:
#                           O dueto inédito entre Elis Regina e Maria Rita para um comercial em celebr
# Displaying 1 of 1 matches:
# ce a letra e história por trás sabe, que jamais Elis cantaria esta canção com um sorriso no rosto. M
# Displaying 1 of 1 matches:
#                                    Qq coisa que Elis esteja é pura obra de arte. Parabéns!!!
# Displaying 1 of 1 matches:
#  Que coisa linda!!! Nostalgia pura! Maria Rita, Elis e Volks, tudo de mais lindo reunido! Eu ainda p
# Displaying 1 of 1 matches:
# ra mim é o melhor que já vi em toda minha vida. Elis Regina e Maria Rita juntas. ❤❤❤❤❤
# Displaying 1 of 1 matches:
#                                             Amo Elis ,amo Maria Rita @@@❤❤❤❤❤❤
# Displaying 1 of 1 matches:
#                                                 Elis Regina é atemporal
# Displaying 1 of 1 matches:
#   Que trabalho maravilhoso!!! Emocionante ver a Elis com a Maria !!!!
# Displaying 1 of 1 matches:
#                                           Cara, Elis sempre emociona, a letra foi de uma época marca
# Displaying 1 of 1 matches:
# tico,chegou a dar uma certa emoção. eternamente Elis 👏🏾👏🏾👏🏾👏🏾
# Displaying 1 of 1 matches:
#                             Isso mostra o qto a Elis é IMORTAL INESQUECÍVEL INIGUALÁVEL. Maria Rita
# Displaying 1 of 1 matches:
#  Viva a Volkswagen que apoiou a ditadura!!! E a Elis Regina que revira no túmulo com essa propaganda
# Displaying 1 of 1 matches:
#                                            esse Elis Regina canta muito hem, ficou ótima, agora só f
# Displaying 1 of 1 matches:
#                          Linda homenagem a VW , Elis Regina, Maria Rita, Belchior e acima de tudo ao
# Displaying 1 of 1 matches:
#         Impossível não se emocionar!!! Quem ama Elis e Maria Rita!! Caramba!!!!!
# Displaying 1 of 1 matches:
# ar que esse comercial é de grande ironia pois a Elis Regina era opositora à ditadura
# Displaying 1 of 1 matches:
# ente do choque que minha mãe levou quando viu a Elis no jornal A Folha de São Paulo dentro do caixão
# Displaying 1 of 1 matches:
# ! Mostra amores eternos do Brasil como a eterna Elis e a Kombi Volkswagen, ameeeeiii! Um toque de al
# Displaying 1 of 1 matches:
#                                               A Elis Regina escolheu cantar numa fábrica para os ope
# Displaying 1 of 1 matches:
#                                                 Elis jamais aceitaria isso em vida. Desrespeitoso e
# Displaying 1 of 1 matches:
#                               Hilario musica de Elis contra ditadura militar na wolks que sempre apo
# Displaying 1 of 1 matches:
#                          A Volkswagen colocar a Elis na propaganda chega a ser estapafúrdio. Porque
# Displaying 1 of 1 matches:
#                                  Espetacular!!! Elis e Belchior! Caiu até um "cisco" no meu olho...
# Displaying 1 of 1 matches:
#                       Bela homenagem, à querida Elis Regina ! Parabéns Volkswagem, lindo comecial.
# Displaying 1 of 1 matches:
# stao cogitando de processo pela IA utilizada da Elis Regina na propagando...por favor né gente!!. Qu
# Displaying 1 of 1 matches:
# nvolvendo a Volks. Mas essa não, essa na voz de Elis é um símbolo nacional.
# Displaying 1 of 1 matches:
# abia que a outra mulher do comercial é filha da Elis e não conhecia a música, mas é um bom comercial
# Displaying 1 of 1 matches:
# éns pelo vídeo maravilhoso! Emocionante demais! Elis Regina e Maria Rita, uma música que é inesquecí
# Displaying 1 of 1 matches:
# e acabando de chorar aqui. Saudosa "pimentinha" Elis sempre no nosso coração.♥️🌶️
# Displaying 1 of 1 matches:
#                                                 Elis se revirou no túmulo
# Displaying 1 of 1 matches:
# paganda mais linda! Além dessa bela homenagem a Elis Regina, lembrei meu pai que infelizmente não es
# Displaying 1 of 1 matches:
# niversário 🎂🎁 d 70 , Fora a homenagem da rainha Elis Regina com a filha 🙏. Quem nunca teve um Fusca
# Displaying 1 of 1 matches:
# eu Deus! Me arrepiei aqui e com essa música com Elis e com Maria Rita acabou comigo.
# Displaying 1 of 1 matches:
# i com a locução da Maria Alice Vergueiro. Ver a Elis num vídeo junto com a Maria Rita mexeu demais a
# Displaying 1 of 1 matches:
#            Genial! Emocionante para quem admira Elis e Maria Rita.
# Displaying 1 of 1 matches:
# o aos que significavam em sua gênese. A cantora Elis e essa obra de Belchior outro grande músico, co
# Displaying 1 of 1 matches:
#      Uaaauuu ....😁👏👏👏👏 ...que incrível ...botar Elis Regina e sua filha Maria Rita juntas ....muito
# Displaying 1 of 1 matches:
# a VW no passado e o que já é o futuro, e quando Elis aparece ... MEU DEUS !!!! Galerinha dos anos 70
# Displaying 1 of 1 matches:
#             É uma bela homenagem a inesquecível Elis
# Displaying 1 of 1 matches:
# l perfeito. É impossível não se emocionar com a Elis e a Maria Rita cantando juntas, e as imagens de
# Displaying 1 of 1 matches:
#                                                 Elis Regina igual boneco de vídeo game
# Displaying 1 of 1 matches:
#                            Eu achei a imagem da Elis muito artificial, o olhar é inexpressivo. Parec
# Displaying 1 of 1 matches:
#  lindo! Fiquei emocionado em ver a nossa eterna Elis "cantando" com a sua filha.
# Displaying 1 of 1 matches:
#  (dir. personalidade) que só à pessoa pertence. Elis cantou para operários da Volks, não para vender
# Displaying 1 of 1 matches:
# a anos nao via um comercial lindo na estetica e Elis enternizada. Parabens a familia que autorizou A
# Displaying 1 of 1 matches:
#                              Isso é um CRIME!!! Elis NUNCA Faria essa propaganda pra uma empresa que
# Displaying 1 of 1 matches:
#  comercial lindo, mas, preocupante. Colocaram a Elis dentro de uma Kombi...Isso nunca aconteceu. Daq
# Displaying 1 of 1 matches:
# ando aqui, além de ser incrível ver a grandiosa Elis Regina cantando ao lado de sua filha Maria Rita
# Displaying 1 of 1 matches:
#  uma belissima composição, agora criticamente a Elis era completamente contra o Regime Ditatorial Mi
# Displaying 1 of 1 matches:
#  o repertório maravilhoso dessa estrela chamada Elis Regina.
# Displaying 1 of 1 matches:
# a ditadura se utilizando da imagem e da obra de Elis Regina é uma ação aviltante à finada cantora, u
# Displaying 1 of 1 matches:
#                                  Poderiam por a Elis de "IA" indo oela eatrada na "corujinha", enqua
# Displaying 1 of 1 matches:
#                                                 Elis nunca aprovaria a imagem dela em propaganda de
# Displaying 1 of 1 matches:
#              Chorei muito. Que homenagem linda. Elis eterna.
# Displaying 1 of 1 matches:
#               Tem gente fazendo mimimi porque a Elis fazia shows pra arrecadar fundos justamente pra
# Displaying 1 of 1 matches:
#          Senti o cheiro de gasolina da Kombi de Elis daqui de casa. #ValeuVW só quem tem um pra pode
# Displaying 1 of 1 matches:
#             Maria Rita é uma grande artista mas Elis tem um brilho diferente
# Displaying 1 of 1 matches:
#  Por mais sorrisos lindos da Maria Rita! Salve, Elis ♥
# Displaying 1 of 1 matches:
#                            Lindo demais.... Amo Elis e Maria Rita
# Displaying 1 of 1 matches:
# rme com a memória desses grandes ícones que são Elis Regina e Belchior.
# Displaying 1 of 1 matches:
#  criadores, realizadores e a própria família da Elis em embarcar nessa ideia genial, a arte sempre t
# Displaying 1 of 1 matches:
#  hipocrisia da Volkswagen, não? Usar justamente Elis e essa música do Belchior para fazer propaganda
# Displaying 1 of 1 matches:
# eia foi unir trechos da música interpretada por Elis com a história da volks que representam a memór
# Displaying 1 of 1 matches:
# unto a mãe. Parabéns pela belíssima homenagem a Elis e propaganda!
# Displaying 1 of 1 matches:
#                                      Coloquem a Elis dentro do carro na foto capa desse vídeo que aí
# Displaying 1 of 1 matches:
# almente por que aparece mãe e filha juntas, amo Elis Regina ❤
# Displaying 1 of 1 matches:
#                                               A Elis virou Fábio Pochart?
# Displaying 1 of 1 matches:
# ramba esse comercial conseguiu me emocionar amo Elis Regina. E tenho tantas lembranças em carros da
# Displaying 1 of 1 matches:
#                                   Não conheci a Elis mas chorei com a musica😢❤ Obrigado: Volkswagen.
# Displaying 1 of 1 matches:
#                            Gosto demais da dona Elis Regina
# Displaying 1 of 1 matches:
# orei de emoção, muitas histórias num só vídeo ! Elis única ! Parabéns!
# Displaying 1 of 1 matches:
# R por esse filme lindo! Além de emocionante ver Elis contracenando com Maria Rita, senti minha famíl
# Displaying 1 of 1 matches:
# ho as lágrimas sempre que vejo, pura emoção ver Elis Regina e Maria Rita juntas, e que delícia toda
# Displaying 1 of 1 matches:
#                          Muito bom. Consigo ver Elis com a filha adulta. Comerciais da Volkswagen se
# Displaying 1 of 1 matches:
# do na letra da música. Sem contar as brilhantes Elis (imortal) e Maria Rita. Chocada!!!! Há tempos q
# Displaying 1 of 1 matches:
#                                               A Elis do PS5 tá surreal. Kkkk
# Displaying 1 of 1 matches:
# anformaram no oposto uma música de crítica, que Elis interpretou mostrando toda a insatisfação, a in
# Displaying 1 of 1 matches:
# lks!! Muito Emocionante, na hora que apareceu a Elis da Regina, fez lembrar da minha Falecida Mãe di
# Displaying 1 of 1 matches:
#  Poderiam colocar um vídeo real dela cantando a Elis não é uma inteligência artificial nunca deve se
# Displaying 1 of 1 matches:
#  do quê uma propaganda, é uma linda homenagem a Elis Regina e um presente a Maria Rita! Me arrepiei
# Displaying 1 of 1 matches:
# Wolks colaborou com a ditadura militar no pais. Elis se opôs ao regime pervesso. Pra miim o comercia
# Displaying 1 of 1 matches:
# vidade, seu conceito histórico e mais colocar a Elis que com a cabeça e emoções que tinha na época e
# Displaying 1 of 1 matches:
# ão chorar. Que trabalho lindo!!!!! Nossa eterna Elis Regina ❤️
# Displaying 1 of 1 matches:
# , muito top comercial!!! Cantora de verdade !!! Elis Regina e Maria Rita peço desculpas pela deturpa
# Displaying 1 of 1 matches:
#  gravado em nossos corações ! Linda homenagem a Elis Regina e família !
# Displaying 1 of 1 matches:
#                                      Aberração! Elis e Belchior se reviram no caixão. A VOLKSWAGEN A
# Displaying 1 of 1 matches:
#                            Nem se ressuscitar a Elis Regina , vão conseguir vender esse novo modelo
# Displaying 1 of 1 matches:
#                              Incrível!! Recriar Elis Regina cantando c/ sua filha Maria Rita foi fan
# Displaying 1 of 1 matches:
#                                                 Elis não faria propaganda para a wolkswagen, pois sa
# Displaying 1 of 1 matches:
# ,Maria Rita é uma diva da música brasileira,e a Elis é a Pelé das cantoras
# Displaying 1 of 1 matches:
#  Volkswagen não era pró ditadura?🤔🤔 Os ossos de Elis ,se ainda existirem, se reviram em seu jazigo.
# Displaying 1 of 1 matches:
#           Parabéns, que coisa mais linda revê a Elis Regina e sua filha Maria Rita, lindo demais ame
# Displaying 1 of 1 matches:
# l fica ainda mais emocionante para quem é fã de Elis Regina e Maria Rita. Muito amor por essas duas
# Displaying 1 of 1 matches:
# ações sobre trabalhadores à polícia no período. Elis Regina se revira no túmulo
# Displaying 1 of 1 matches:
#         Me arrepiei vendo que propaganda linda. Elis eterna ❤
# Displaying 1 of 1 matches:
#                                                 Elis chegando de Kombi foi de arrepiar
# Displaying 1 of 1 matches:
#                                               A Elis Regina deve estar se revirando no túmulo. 😢
# Displaying 1 of 1 matches:
#   Isso só pode ser um sacarmos com a memória da Elis
# Displaying 1 of 1 matches:
# anto essa. Parabéns a VW pela linda homenagem a Elis Regina.
# Displaying 1 of 1 matches:
# causa da música, mas levei um susto quando vi a Elis Regina
# Displaying 1 of 1 matches:
#   Eu chorei de emoção por ser fã da Elis. Mas a Elis se viva ia chorar por ver uma empresa de origem
# Displaying 1 of 1 matches:
# clusive acho que podiam lançar uma kombi versão Elis de verdade com alguns opcionais estéticos.
# Displaying 1 of 1 matches:
# video poderia ficar só no dueto da Maria Rita e Elis Regina. Alguns trechos são totalmente dispensáv
# Displaying 1 of 1 matches:
# e outro planeta: SP2 Além obviamente de reviver Elis pra uma geração que gosta de Air cooled, que só
# Displaying 1 of 1 matches:
#            Só eu que achei espantoso essa IA da Elis Regina?
# Displaying 1 of 1 matches:
# ente pensada ❤. Dá uma emoção enorme assistir a Elis e a Maria Rita
# Displaying 1 of 1 matches:
# a propaganda sem pesquisar contextos da vida da Elis Regina, vai achar lindo mesmo
# Displaying 2 of 2 matches:
#       VW apoiou a dotadura molitar na epoca e a Elis Regina era contra... Fico me perguntando se a E
# s Regina era contra... Fico me perguntando se a Elis aceitaria esse comercial numa boa.
# Displaying 1 of 1 matches:
# ntas nunca chorei tanto assistindo um comercial Elis voce e eterna.
# Displaying 1 of 1 matches:
#                           Nem a ressurreição da Elis faria alguém pagar 400.000 reaisy numa Kombi 😅
# Displaying 1 of 1 matches:
# sca de alguns trocados. Alguém perguntou para a Elis Regina ou o Belchior se eles queriam a música d
# Displaying 1 of 1 matches:
#                                                 Elis cantou e militou contra a ditadura. Enquanto es
# Displaying 1 of 1 matches:
#           Legal a homenagem e taus, mas a IA da Elis ficou ruim pra uma empresa do porte da VW!
# Displaying 1 of 1 matches:
#      O deepfake está bem quando a câmera pega a Elis do lado direito, mas do lado esquerdo não.
# Displaying 1 of 1 matches:
# esa foi uma apoiadora da ditadura, acredito que Elis Regina como uma combatente do regime cruel em q
# Displaying 1 of 1 matches:
#                                     Sem dúvidas Elis adoraria ter visto sua imagem associada a uma e
# Displaying 1 of 1 matches:
#                                                 Elis para sempre Elis!..❤️
# Displaying 1 of 1 matches:
#      Só o fato da WV ter apoiado a ditadura e a Elis ser contra a ditadura, a familia e os parceiros
# Displaying 1 of 1 matches:
#                            Que lindo comercial. Elis Regina, que saudade da pimentinha. E ainda cant
# Displaying 1 of 1 matches:
#                             Só por IA mesmo pra Elis fazer uma propaganda de uma empresa que financi
# Displaying 1 of 1 matches:
# inho. Esse vídeo veio na hora certa e ainda com Elis Regina q era a cantora q mais escutava na época
# Displaying 3 of 3 matches:
#                         Chorei que coisa linda, Elis Regina, Maria Rita, Belckior e Volks que meu pa
#  era apaixonado pela Volks e eu apaixonada pela Elis Regina. Quanta saudade dos dois: meu pai e Elis
# Elis Regina. Quanta saudade dos dois: meu pai e Elis Regina. Parabéns 👏
# Displaying 1 of 1 matches:
#                                     Será q se a Elis estivesse entre nós ela faria um comercial pra
# Displaying 1 of 1 matches:
# de "homenagem" é muito desrespeitosa pelo que a Elis lutou.. a necromancia virtual tende a crescer v
# Displaying 1 of 1 matches:
# do ainda melhor, não sei a montagem do rosto da Elis ficou meio BUGADO, parece que a montagem do ros
# Displaying 1 of 1 matches:
# de e pela escolha desta história. A potência de Elis é indiscutível. E fazer este "encontro" de mãe
# Displaying 1 of 1 matches:
#                                                 Elis deve estar se revirando no túmulo 😅
# Displaying 1 of 1 matches:
#                                               A Elis q cantou para apoiar os metalúrgicos nunca fari
# Displaying 2 of 2 matches:
#                            Na época da ditadura Elis estava literalmente ao lado de Lula na greve do
# A VW é acusada de apoiar o nazismo. A imagem da Elis não nega que foi muito mal pela I.A..
# Displaying 2 of 2 matches:
# ito top esse comercial, muito emocionante adoro Elis aliás, AMO Elis
# ercial, muito emocionante adoro Elis aliás, AMO Elis
# Displaying 1 of 1 matches:
#     A ideia foi legal,só economizaram no CGI da Elis Regina.
# Displaying 1 of 1 matches:
# e Belchior e com uma interpretação impecável de Elis Regina ❤
# Displaying 1 of 1 matches:
#  Eu achei lindo, mas acho que tentaram mirar na Elis e acertaram na Magalu
# Displaying 1 of 1 matches:
# mercial com Elie Regina inteligência artificial Elis que foi presa pela ditadura. Se fosse viva hoje
# Displaying 1 of 1 matches:
# sisti mil vezes. Parabéns ❤ aprendi a gostar de Elis através da minha mãe que é fã e acabei sendo ta
# Displaying 1 of 1 matches:
#           Obrigado ao eterno Belchior, à eterna Elis e à toda equipe de produção deste comercial, fo
# Displaying 1 of 1 matches:
# co. Impossível não se arrepiar com a entrada da Elis Regina. Fico pensando no quanto a Maria Rita de
# Displaying 1 of 1 matches:
#  o oposto, é um desrespeito a tudo q Belchior e Elis Regina acreditavam. Não caiam no sentimentalism
# Displaying 1 of 1 matches:
# ial emocionante que rever a voz da inesquecível Elis Regina e cantando junto com a sua filha Maria R
# Displaying 1 of 1 matches:
# a Uol e a globo falando mal e questionando se a Elis teria concordado, ao invés de agradecer pela qu
# Displaying 1 of 1 matches:
#       Parabéns à VW. Relembrando dois gigantes: Elis Regina e Belchior.
# Displaying 1 of 1 matches:
# e assisto! Me arrancou lágrimas... Simplesmente Elis ❤
# Displaying 1 of 1 matches:
#                                                 Elis e Floripa ❤❤❤❤
# Displaying 1 of 1 matches:
#  então... A idéia da junção da Maria Rita com a Elis foi muito feliz. Muita sensibilidade. Aos críti
# Displaying 1 of 1 matches:
#          Amei, achei muito emocionante ❤❤❤ vê a Elis e depois lembrar que foi só uma inteligência é
# Displaying 1 of 1 matches:
# sa que apoiou e financiou a ditadura. A luta de Elis Regina nunca vai ser esquecida.
# Displaying 1 of 1 matches:
#                                     Se a voz da Elis já era horrível de aturar, com essa dupla de dn
# Displaying 2 of 2 matches:
# grandes canções de PROTESTO do grande Belchior. Elis Regina também foi uma pessoa que protestava con
#  Eu sinceramente gostaria de saber a opinião de Elis Regina e Belchior sobre essa empresa usar suas
# Displaying 1 of 1 matches:
#               👏👏👏 Gostei da homenagem à cantora Elis Regina e à Volkswagen . Clima de saudosismo e l
# Displaying 1 of 1 matches:
#                                    Eu era fã de Elis qdo eu era adolescente em 2000 e a galera falav
# Displaying 1 of 1 matches:
# oras!! Quanta saudade!! A propaganda trazendo a Elis e Maria Rita juntas fez voltarem lembranças pre
# Displaying 1 of 1 matches:
#                                               A Elis está se revirando no túmulo depois dessa :(
# Displaying 1 of 1 matches:
#     Essa foi a melhor propaganda do ano,saudade Elis adorava ela 😢❤🎉
# Displaying 1 of 1 matches:
#          Belíssimo vídeo. O fato de pensarem na Elis atesta a relevância da Volkswagen no imaginário
# Displaying 2 of 2 matches:
# ropaganda lindíssima , emocionante e criativa , Elis Regina atemporal , música emblemática do TB bri
# gina a emoção da Maria , mesmo que digitalmente Elis tá ali , ao lado da filha juntas cantando esse
# Displaying 1 of 1 matches:
#           Me emocionou demais! Vocês arrasaram! Elis para sempre!! Maior cantora do Brasil!!
# Displaying 1 of 1 matches:
#                                                 Elis não faria propaganda para vocês, por favor. Apa
# Displaying 1 of 1 matches:
# anda pra uma empresa que financiava a ditadura. Elis deve tá pistola das ideias lá no além.
# Displaying 1 of 1 matches:
# ia emocionante, ainda relembramos de BELCHIOR e Elis Regina demais abraços Roberto Filho Radialista
# Displaying 1 of 1 matches:
#  escolha da persuasão por meio da música (com a Elis e a referência ao Belchior) que suscita a memór
# Displaying 1 of 1 matches:
# arte 🖼️ a história desse clip. Lindo demais ver Elis Regina e sua filha ❤
# Displaying 1 of 1 matches:
# A ESQUINA" . Considero uma afronta ao legado de Elis e Belchior. A Empresa sabiamente se envolveu co
# Displaying 1 of 1 matches:
#                     Parabéns pela homenagem com Elis e Maria Rita 😢😢
# Displaying 1 of 1 matches:
# ca" fazendo os mortos ressucitarem. Se trazem a Elis Regina para vender Kombis, imagine o que se pod
# Displaying 1 of 1 matches:
# e senti nó na garganta vendo um comercial. Viva Elis e Viva Belchior.
# Displaying 1 of 1 matches:
#                                                 Elis se revira no túmulo. Alguns direitos da persona
# Displaying 2 of 2 matches:
#                                 Que saudade, de Elis Regina ,que voz linda.Amo Maria Rita ótima cant
# voz linda.Amo Maria Rita ótima cantora.Filha de Elis Regina ❤😂
# Displaying 1 of 1 matches:
# mente apoiou a ditadura que perseguiu a própria Elis Regina. Nem mais os mortos podem descansar hoje
# Displaying 1 of 1 matches:
# ores da época, que essa música foi cantada pela Elis para apoiar os trabalhadores da Volks que havia
# Displaying 2 of 2 matches:
#  brincadeira! Ou são muito sonsos ou se fingem! Elis lutou arduamente contra a ditadura, e a família
#  e ajudou a ditadura, e foi contra tudo o que a Elis lutou e era) revive-la pra fazer uma propaganda
# Displaying 1 of 1 matches:
#  de três pontos numa Kombi, o qual, no tempo da Elis Regina, era sub-abdominal.
# Displaying 1 of 1 matches:
# ida. Para quem conhece a letra e a angústia que Elis sofria ao cantá-la é que pode compreender que d
# Displaying 1 of 1 matches:
#                            Lindaaaa saudades de Elis
# Displaying 1 of 1 matches:
#  quem não arrepiou com esse comercial... Te amo Elis
# Displaying 1 of 1 matches:
#                                                 Elis Regina e Belchior se revirando ao ver que as pa
# Displaying 1 of 1 matches:
#                                   Se a filha da Elis Regina, que é o parente mais próximo, autorizou
# Displaying 1 of 1 matches:
#                                     Lindo ver a Elis na propaganda! Emocionante! Aprovadíssima
# Displaying 1 of 1 matches:
# um cantora tão carismática como a nossa cantora Elis Regina
# Displaying 1 of 1 matches:
#                                                 Elis vive
# Displaying 1 of 1 matches:
#                                                 Elis Magalu
# Displaying 1 of 1 matches:
# ria de 70 anos da Volkswagen, na qual a cantora Elis Regina, morta em janeiro de 1982, é trazida “de
# Displaying 1 of 1 matches:
#                          Saudade do Belchior da Elis e dos bons e velhos tempos ❤❤❤❤
# Displaying 1 of 1 matches:
#                                    Queria ver a Elis fazer exame do bafômetro......🥂🥂🥂🥂🥂
# Displaying 1 of 1 matches:
#                                               A Elis criticava MUITO essa montadora que , de fato, f
# Displaying 1 of 1 matches:
#                      Que lindo hubiera sido que Elis estuviera realmente allí las amo a las dos Mart
# Displaying 1 of 1 matches:
#                    Sou muito fã do Belchior, da Elis e da Maria Rita. Impossível não amar esse comer
# Displaying 1 of 1 matches:
#            Linda homenagem, e muito bom rever a Elis mesmo que artificialmente. Maravilhosa sempre.
# Displaying 1 of 1 matches:
# oi boa. Mas na prática...sei lá, não acho que a Elis aprovaria algo assim. Ainda mais com essa músic
# Displaying 1 of 1 matches:
#           Sobre o comercial da Volkswagen com a Elis Regina: Não é "arte". Não é igual a fazer uma a
# Displaying 1 of 1 matches:
#     Nunca senti tanta emoção em uma propaganda! Elis ontem, hoje e sempre será - na verdade foi uma
# Displaying 1 of 1 matches:
#                                                 Elis ❤
# Displaying 1 of 1 matches:
# ica contra Volkswagem por comercial que recriou Elis Regina.." Os caras não tem mesmo o que fazer, a
# Displaying 1 of 1 matches:
#                                           Pobre Elis Regina!!!
# Displaying 2 of 2 matches:
#  a propaganda do ano......me tirou lagrimas ver Elis ......Viva Elis eterna........ parabéns as pess
#  ano......me tirou lagrimas ver Elis ......Viva Elis eterna........ parabéns as pessoas que fizeram
# Displaying 1 of 1 matches:
# mercial que realmente fez diferença no meu dia, Elis Regina e uma Kombi corujinha são uma dupla ines
# Displaying 1 of 1 matches:
# rabéns #VWBrasil , linda campanha publicitária, Elis e Maria Rita juntas amei , amo interpretação de
# Displaying 1 of 1 matches:
#                                 Meu pai adorava Elis 💗
# Displaying 2 of 2 matches:
# ibuiu com a ditadura militar se aproveitando de Elis Regina, uma cantora que sempre cantou contra a
# tra a ditadura. Nojento demais. Aproveitadores. Elis jamais aprovaria essa nojeira
# Displaying 1 of 1 matches:
# do Bolo, gente, foi D+ Maria Rita num dueto com Elis Regina. Mesmo sendo uma computação gráfica.. fo
# Displaying 1 of 1 matches:
#              Nossa, dei uma chorada forte aqui. Elis Regina me lembra ao meu pai. Ele tá vivo, ´ta b
# Displaying 1 of 1 matches:
# ial é muito top conseguiram recriar a imagem de Elis Regina a filha dela a Maria Rita têm a voz inde
# Displaying 1 of 1 matches:
#                       podiam ter usado IA. Essa Elis tá um pouco diferente rs
# Displaying 1 of 1 matches:
# nanciava tortura durante a ditadura e a própria Elis arrecadava dinheiro pra apoiar a greve dos próp
# Displaying 1 of 1 matches:
#                                  Não sou Fãn de Elis Regina, porém ficou nota 10 ! Lembrou bastante
# Displaying 1 of 1 matches:
#                                             Ver Elis viva novamente e emocionante, ver Belchior lemb
# Displaying 1 of 1 matches:
# fora de contexto!! E essa tecnologia usada para Elis ficou bizarra, macabra e hilaria! A mulher morr
# Displaying 1 of 1 matches:
#                 Coitado dos queridos Belchior e Elis 😢
# Displaying 1 of 1 matches:
#  a Kombi (e a Elis, embora todo mundo saiba que Elis vive!).
# Displaying 1 of 1 matches:
#  Morri de chorar , perfeito amo essa música amo Elis q presente esse comercial ❤
# Displaying 1 of 1 matches:
# r her daughter and the millions of adoring fans Elis had/has.
# Displaying 1 of 1 matches:
#  morta, que não se sabe sequer se viva fosse, a Elis autorizaria a imagem, além do mais para uma fab
# Displaying 1 of 1 matches:
#                                                 Elis Regina nunca aceitaria fazer essa propaganda, e
# Displaying 1 of 1 matches:
# u da propaganda? Pode começar a xingar porque a Elis era de esquerda. Huahuahua
# Displaying 1 of 1 matches:
# comercial é lindo e emocionante, mas queria que Elis e Belchior estivessem vivos para que pudessem f
# Displaying 1 of 1 matches:
#                        Desrespeito perverso com Elis e Belchior ,fizeram essa música de protesto con
# Displaying 1 of 1 matches:
#                                     Certeza q a Elis Regina nunca aprovaria isso!!
# Displaying 1 of 1 matches:
#                                                 Elis Regina, uma das maiores combatentes da ditadura
# Displaying 1 of 1 matches:
#                                                 Elis JAMAIS gostaria dessa propaganda. Ainda mais po
# Displaying 1 of 1 matches:
# ionava tanto com uma propaganda. A Maria Rita e Elis Regina deram um show juntamente com a empresa d
# Displaying 1 of 1 matches:
#                                               A Elis concordou ou concordaria com esse comercial? Is
# Displaying 1 of 1 matches:
#                        Que comercial tenebroso, Elis Regina se revira no caixão se visse a música se
# Displaying 1 of 1 matches:
#           Mas apoiar a ditadura que perseguiu a Elis é de boa, né rs
# Displaying 3 of 3 matches:
# otiva em pensar que Maria Rita tinha 4 anos qdo Elis nos deixou e essa semelhança de Deus na voz! Já
# i e revi o vídeo várias vezes e nunca me canso! Elis para sempre .... eternamente Elis! Parabéns a t
# iros(as) que amaram, amam e amarão nossa eterna Elis Regina!
# Displaying 1 of 1 matches:
#  que essa turma chatos hoje...nada demais rever Elis cantando foi só emoção
# Displaying 1 of 1 matches:
#  de muito bom gosto! Muito bonita a homenagem à Elis Regina! 👏👏👏👏👏
# Displaying 1 of 1 matches:
#                               Maravilhoso!!!Amo Elis !
# Displaying 1 of 1 matches:
# uição aos opositores da ditadura, se Belchior e Elis estivessem vivos jamais aceitariam o uso da let
# Displaying 1 of 1 matches:
# descupar por ter apoiado a ditadura militar que Elis e Belchior tanto combatiam.
# Displaying 1 of 1 matches:
#                           Se eu que não conheci Elis em vida, me emociono com essa propaganda, imagi
# Displaying 1 of 1 matches:
#                   Ok, ficou muito bom, mesmo. À Elis cabem todas as homenagems, pois ela é gigante.
# Displaying 1 of 1 matches:
# mos esquecer que a VW apoiava a ditadura a qual Elis Regina era contra!
# Displaying 1 of 1 matches:
#                                        Vendeu a Elis barato, mas diga me; quem não precisa de dinhei
# Displaying 1 of 1 matches:
# adura militar. E eu achei a recriação por AI da Elis Regina cantando essa música toda feliz de pessi
# Displaying 1 of 1 matches:
#              @Volkswagen parabéns, chorei vendo Elis sorrindo pra filha e lembrei demais dos passeio
# Displaying 1 of 1 matches:
#                                      tadinha da Elis :/ era comunista e depois de morta botam ela se
# Displaying 1 of 1 matches:
#                            Emocionante assistir Elis e Maria Rita! Viva a IA.
# Displaying 1 of 1 matches:
#  mas a poesia tem sua força. Agora, animação da Elis caiu no vale da estranheza. E Volkswagen só pre
# Displaying 1 of 1 matches:
# ry time I watch it. I love it. I've ordered the Elis Regina vinyl because I can't stop singing the s
# Displaying 1 of 1 matches:
# o de Maria Rita ao assistir o vídeo finalizado. Elis sorriu com seu sorriso largo e feliz. E nós enc
# Displaying 1 of 1 matches:
#                Achei bizarro, e também acho que Elis não concordaria por conta de sua posição políti
# Displaying 1 of 1 matches:
#               O único erro dessa propaganda é a Elis estar de cinto de segurança. Huahuahua
# Displaying 1 of 1 matches:
#                                                 Elis e Belchior devem ter se revirado no túmulo.
# Displaying 1 of 1 matches:
#                                            Se a Elis estivesse viva jamais teria feito essa propagan
# Displaying 1 of 1 matches:
#                    Não acompanhei a carreira da Elis Regina, pois não tinha nascido quando ela falec
# Displaying 1 of 1 matches:
#  surpreendeu quando descobriu que eu gostava de Elis Regina,.Parabéns WW isso sim é uma propaganda d
# Displaying 1 of 1 matches:
# uuuuuper jóia !!!!!.... q deliiiiiicia assistir Elis tão presente!!! Obrigada Volkswagen!❤️
# Displaying 1 of 1 matches:
# gen, Maria Rita maravilhosa, salve nossa eterna Elis Regina!!!!!!!!!
# Displaying 1 of 1 matches:
# gado VW por este lindo vídeo e pelo homenagem a Elis e ao Belchior!!
# Displaying 1 of 1 matches:
# ica o tempo nos leva a sonhar, coisas boas, com Elis então sou fã de carteirinha.
# Displaying 1 of 1 matches:
# nvestigando a Volkswagen por causa da imagem da Elis criada por IA...
# Displaying 1 of 1 matches:
#  somos iguais a nossos pais, segunda será que a Elis Regina participaria desse comercial? ela q foi
# Displaying 1 of 1 matches:
# !!!!! Merece o maior prêmio publicitário!!!!!!! Elis Regina , com certeza aplaude de pé e os filhos
# Displaying 1 of 1 matches:
#                                               a Elis Regina era contra a ditadura que vocês apoiaram
# Displaying 1 of 1 matches:
#    Meu Deus as vozes delas juntos. Imagina se a Elis tivesse viva e cantando um dueto com sua própri
# Displaying 1 of 1 matches:
#                     Arrepia tudo no momento que Elis aparece e de repente filha e mãe cantam juntas
# Displaying 5 of 5 matches:
# ha sonora, especialmente ao incluir as cantoras Elis Regina e Maria Rita, é um exemplo interessante
# A escolha de canções icônicas interpretadas por Elis Regina e sua filha Maria Rita não é apenas uma
# : A relação entre mãe e filha, representada por Elis e Maria Rita, simboliza uma continuidade cultur
# e consumidores, fazendo com que tanto os fãs da Elis quanto os da Maria Rita se sintam representados
# swagen com as trilhas sonoras interpretadas por Elis Regina e Maria Rita é rica em potencial emocion
# Displaying 1 of 1 matches:
# eria ter sido outra, em respeito às memórias da Elis e do Belchior, principalmente pela crítica expl
# Displaying 1 of 1 matches:
#                Cara que propaganda mais linda , Elis Regina imortal ,tão linda quanto antes e a filh
# Displaying 1 of 1 matches:
#  Lindo demais. Conseguiram reunir duas paixões, Elis e Volkswagen.
# Displaying 1 of 1 matches:
#                             Ressuscitaram até a Elis ! Sensacional!! Parabéns
# Displaying 1 of 1 matches:
#                                                 Elis Regina não satisfeita em vir ao mundo com essa
# Displaying 1 of 1 matches:
# m a imagem de Belchior à presença arrepiante de Elis Regina. Já me arrepiei umas três vezes!
# Displaying 1 of 1 matches:
#  do nosso amor e da nossa saudade. Gravações de Elis existem aos borbotões, nossa rainha foi bem cap
# Displaying 1 of 1 matches:
#                                           Kkkkk Elis se revirando mudando todo o contexto da crítica
# Displaying 1 of 1 matches:
#  gosto dessa música, nem da Maria Rita , nem da Elis Regina, muito menos dos carros da Wokswagen. Af
# Displaying 1 of 1 matches:
#                                 Só assim para a Elis Regina aparecer numa propaganda da Volkswagen,
# Displaying 1 of 1 matches:
#                                  Irônico usar a Elis pra vender carro em um comercial de uma marca q
# Displaying 1 of 1 matches:
#    VW parabéns por essa propaganda sensacional. Elis Regina era realmente uma cantora excepcional. A
# Displaying 2 of 2 matches:
# nal me emocionei em ver Mãe e filhas juntas amo Elis Regina e amo Maria Rita Elis Maria e Rita Regin
#  filhas juntas amo Elis Regina e amo Maria Rita Elis Maria e Rita Regina ❤❤❤❤❤❤❤❤❤❤❤
# Displaying 1 of 1 matches:
#                    Amei essa propaganda. Grande Elis
# Displaying 1 of 1 matches:
# muito bem, valorizando a figura da inesquecível Elis Regina e de quebra valorizou o que é família e
# Displaying 1 of 1 matches:
#                                          🌾🍂☕ oh Elis , 🍃☁️...
# Displaying 1 of 1 matches:
# i... Lindo comercial. Meu nome é em homenagem a Elis Regina ❤ Parabéns aos criadores
# Displaying 1 of 1 matches:
#           Arrepiei, que propaganda maravilhosa… Elis e Maria Rita, que combo 🥹 Parabéns aos criadore
# Displaying 1 of 1 matches:
#                                                 Elis e Maria Rita cantando Belchior... Acho até que
# Displaying 1 of 1 matches:
#                              Achei fraco, fazer Elis aparecer alguns segundos. Poderia ser bem melho
# Displaying 1 of 1 matches:
# a de imbecís elogiando esse ultraje a imagem de Elis Regina 👏👏👏👏👏
# Displaying 1 of 1 matches:
#                      quem conhece a história da Elis Regina, sabe que ela não concordaria em fazer u
# Displaying 1 of 1 matches:
#                   É uma falta de respeito com a Elis Regina, considerando tudo que a volkswagen fez
# Displaying 1 of 1 matches:
# Meu não sei dizer se gostei ou não deles usar a Elis nessa propaganda Será q ela gostaria
# Displaying 1 of 1 matches:
#                                      Será que a Elis Regina aprovaria?
# Displaying 1 of 1 matches:
#     Maravilhoso … adorei .. grande ideia manter Elis viva e lindo obrigado
# Displaying 1 of 1 matches:
# tei de tudo, principalmente o fundo musical com Elis cantando Belchior, meu conterrâneo.
# Displaying 1 of 1 matches:
# s Maria Rita, parabéns Volkswagen e Saudações a Elis Regina sempre fui seu fã!
# Displaying 1 of 1 matches:
#                            Tenho certeza que se Elis e compositor Belchior estivessem vivos, não iri
# Displaying 1 of 1 matches:
#                             Muito boa ..saudosa Elis Regina..muito bom
# Displaying 1 of 1 matches:
#                                                 Elis Regina ❤
# Displaying 1 of 1 matches:
#                                                 Elis Regina se revirando no túmulo. Em nome do " vil
# Displaying 1 of 1 matches:
#               VW colaborou com o golpe de 1964. Elis foi ameaçada e sofreu perseguição, repúdio e de
# Displaying 1 of 1 matches:
#                                                 Elis provavelmente estaria se remexendo no túmulo se
# Displaying 1 of 1 matches:
#                                                 Elis , uma das maiores Saudades do Brasil , obrigado
# Displaying 1 of 1 matches:
# oisa linda!!! Emocionada demais com a imagem da Elis e da Maria Rita. Parabéns, VW. INCRIVEL.
# Displaying 1 of 1 matches:
#                                                 Elis regina estas viva?¿
# Displaying 1 of 1 matches:
# e propaganda linda, chorei. Foi muito bom ver a Elis e a Maria Rita nesse show de propaganda. ADOREI
# Displaying 1 of 1 matches:
#            Sensacional. Além de rever a Icônica Elis Regina, esse encontro virtual, de mãe e filha c
# Displaying 1 of 1 matches:
#                                Um desrespeito à Elis e ao Belchior. Fora de eixo, bizarro.
# Displaying 1 of 1 matches:
#                        Assustador... aposto que Elis jamais faria comercial usando essa música para
# Displaying 1 of 1 matches:
# am subversivos passando nomes, fotos endereços, Elis Regina era uma ferrenha opositora ao regime por
# Displaying 1 of 1 matches:
# ira Mar Norte e no norte da ilha. Lindo demais! Elis e Maria Rita juntas, com a maravilhosa letra/mú
# Displaying 1 of 1 matches:
#               Não sei se o Belchior e a própria Elis iriam aprovar este comercial. É complicado usar
# Displaying 1 of 1 matches:
#        Chorei ao ver mãe e filha, maravilhosas. Elis eterna ❤
# Displaying 1 of 1 matches:
#                                         So pela Elis e Maria Rita já valeu❤
# Displaying 2 of 2 matches:
#                            Fico imaginando se a Elis ainda estivesse viva... A influência dela não s
# no Brasil uma artista que supere a inesquecível Elis Regina. Principalmente o seu pensamento revoluc
# Displaying 1 of 1 matches:
#                                     Eternamente Elis Regina
# Displaying 1 of 1 matches:
#                                         Imagina Elis participando do comercial de um patrocinador da
# Displaying 1 of 1 matches:
#                                  Só a altura da Elis Regina que parece discrepante, ela era pequena
# Displaying 1 of 1 matches:
#                O bonito dessa propaganda foi vê Elis e Maria Rita! ❤
# Displaying 1 of 1 matches:
# m e o CONAR esta processando a wolks por trazer Elis de volta a vida😮‍💨 o L esta feito
# Displaying 2 of 2 matches:
# Essa combinação entre passado e presente, com a Elis Regina cantando e dirigindo a Kombi antiga enqu
#  única para nós. A combinação da icônica voz da Elis Regina com a nostalgia da Kombi antiga, certame
# Displaying 1 of 1 matches:
#                              Perguntaram para a Elis se podiam usar ela no comercial? Não sei se ela
# Displaying 1 of 1 matches:
#                                     Saudades da Elis
# Displaying 1 of 1 matches:
#                                        Adorei a Elis de cinto 😂
# Displaying 1 of 1 matches:
#                                     Saudades de Elis !
# Displaying 1 of 1 matches:
# o tempo certíssimo.... incrível! Parabéns! Viva Elis Regina, a arte jamais morre, o artista é muito
# Displaying 1 of 1 matches:
#                                    Eu não curto Elis Regina e nem Maria Rita, não fazem o tipo que p
# Displaying 1 of 1 matches:
#                               Há algo de errado Elis Regina com a Volkswagen 🤔🤔🤔
# Displaying 1 of 1 matches:
#                    Eu não gostei. Além da falsa Elis ter ficado estranha, foi um desrespeito a memór
# Displaying 1 of 1 matches:
# e arrepiar e sair lágrima dos olhos!!! Obrigado Elis - Obrigado Maria- Obrigado Volkswagen!!!
# Displaying 1 of 1 matches:
#                                               A Elis não aceitaria fazer um comercial ou ter sua ima
# Displaying 1 of 1 matches:
# splêndido!!!! Isso mostra que mesmo anos e anos Elis Regina e Belchior tem importância na MPB!! A VW
# Displaying 1 of 1 matches:
# te! Que campanha linda! Parabéns VW! Belchior e Elis com certeza, estão orgulhosos!
# Displaying 1 of 1 matches:
#                        Parabéns pelo comercial. Elis é uma das maiores estrelas que o país já teve/t
# Displaying 1 of 1 matches:
#   REALISMO ASSUSTADOR...Parabéns pela homenagem Elis mereceu!!!...FELIZ 70 ANOS...Rumo á mais 70 de
# Displaying 1 of 1 matches:
# opaganda 👏👏👏👏👏 e linda homenagem a Maria Rita e Elis Regina
# Displaying 1 of 1 matches:
# Bonito comercial, a música me faz lembrar que a Elis Regina criticou muito a ditadura militar com as
# Displaying 1 of 1 matches:
#  apoiava demais a ditadura militar, coisa que a Elis Regina era extremamente contra. Estão tentando
# Displaying 1 of 1 matches:
# nte foi muito bonita e bem bolada ! 🥰❤️ Sdds da Elis ❤
# Displaying 1 of 1 matches:
#                                           Amei. Elis e Maria Rita
# Displaying 1 of 1 matches:
# bi dizendo que é de geração para geração, porém Elis Regina JAMAIS aceitaria participar de uma propa
# Displaying 1 of 1 matches:
#               Apoiadores da ditadura militar, a Elis Regina nunca estaria com vocês
# Displaying 1 of 1 matches:
# l, não vi nada de errado. Se a própria filha da Elis Regina está participando o que os outros tem qu
# Displaying 1 of 1 matches:
#                                                 Elis Regina nunca faria um comercial desse. É uma tr
# Displaying 1 of 1 matches:
#                                               A Elis está parecendo a Luiza da Magalu
# Displaying 1 of 1 matches:
#  que já existiu, nos relembrando o espaço que a Elis tem em nossos corações! E sim! VW marcando gera
# Displaying 1 of 1 matches:
#                                                 Elis se revirando no túmulo ☠️
# Displaying 1 of 1 matches:
#                                               A Elis nunca participaria de uma propaganda de VW cola
# Displaying 1 of 1 matches:
#                                               A Elis Regina não tá mais aqui pra autorizar o uso da
# Displaying 1 of 1 matches:
# ever a excelente cantora e intérprete que foi a Elis Regina!
# Displaying 1 of 1 matches:
#                            Emocionante quando a Elis chega
# Displaying 1 of 1 matches:
#             Incrível, Maria Rita e nossa eterna Elis Regina! 😢❤
# Displaying 1 of 1 matches:
#  o comercial bonito mas se esquecem de que se a Elis regina fosse viva hj ela jamais permitiria a im
# Displaying 1 of 1 matches:
#                  Homenagens maravilhosas a VW , Elis Regina, Maria Rita, Belkior e acima fe tudo ao
# Displaying 1 of 1 matches:
#  mal amadas acham ofensivo a recriação em IA da Elis Regina. Para quem está reclamando, vai aqui o a
# Displaying 1 of 1 matches:
#                                          Eterna Elis Regina. Eu não era vivo, mas vivo agora!
# Displaying 1 of 1 matches:
#                      Gostei muito, mas o CGI da Elis Regina deixou a desejar
# Displaying 1 of 1 matches:
# po pra dentro do fusquinha do meu pai escutando Elis Regina nas fitas cassete dele que eu sempre des
# Displaying 1 of 1 matches:
# ssistindo esse comercial! Lindas e divas eterna Elis e rainha Maria Rita.
# Displaying 1 of 1 matches:
#                Imaginem um show da Maria Rita e Elis Regina nesse dueto maravilhoso!!!!
# Displaying 1 of 1 matches:
#                                    O sorriso da Elis não tem igual .. chego a me arrepiar 😢
# Displaying 1 of 1 matches:
#                                    E no final a Elis passa a Maria Rita...😅😅
# Displaying 1 of 1 matches:
#                                                 Elis se revira no túmulo. Belchior também.
# Displaying 2 of 2 matches:
#                               De péssimo gosto. Elis se reviraria no caixão. Com certeza. Colocar a
# erteza. Colocar a letra de Belchior e a cara da Elis na propaganda da Volkswagen é de uma perversida
# Displaying 1 of 1 matches:
#                                                 Elis Regina deve ta se contorcendo no caixão agora
# Displaying 1 of 1 matches:
# talgia de ver mesmo com inteligência artificial Elis com a filha. Parabéns Volks. Lindo e emocionant
# Displaying 1 of 1 matches:
# o comercial tão lindo e emocionante...eu não vi Elis Regina quando viva pois ela morreu antes do meu
# Displaying 1 of 1 matches:
# ca está aqui e está kombi 2024 vai pra garagem. Elis vive
# Displaying 1 of 1 matches:
# ita homenageando a música popular brasileira de Elis Regina, recriada por Maria Rita e parabéns pelo
# Displaying 1 of 1 matches:
#                                Que lindo usar a Elis pra essa propaganda sendo que a VW fazia lobby
# Displaying 1 of 1 matches:
#                                             SIM Elis , SIM!!!! Sua dor seria maior ainda em perceber
# Displaying 1 of 1 matches:
# is bem produzida. Um estouro!! PARABÉNS, eterna Elis Regina. 🙌❤️
# Displaying 1 of 1 matches:
#     Voltei a infância!!!!! Lindo comercial. Amo Elis e Maria Rita!
# Displaying 1 of 1 matches:
# io sbt de melhor comercial brasileiro em 23 pra Elis Maria Rita é Kombi 😊😊😊😊
# Displaying 1 of 1 matches:
# olhar pro futuro. E o toque de ter Maria Rita e Elis Regina cantando esse clássico juntos é a cereja
# Displaying 1 of 1 matches:
#                           A qualidade do bot da Elis é da mesma qualidade dos carros modernos da VW.
# Displaying 1 of 1 matches:
#                             Nem sou do tempo de Elis Regina e me emocionei com a propaganda, ficou p
# Displaying 1 of 1 matches:
#                               Saudades eternas, Elis
# Displaying 1 of 1 matches:
# Chorei lembrando da minha geração.Fui louco por Elis Regina.Aplausos para quem teve essa Fantástica
# Displaying 1 of 1 matches:
#                                     We love you Elis xx

# %%
# Lista de palavras mais comuns apenas nas sentenças que tiverem a palavra alvo

# Pasta onde estão os arquivos
pasta_corpus = "corpus_comentarios_elis/"
# Palavra alvo
palavra_alvo = "elis"
# Variável que armazenará o textos das sentenças que contenham a palavra alvo em uma única string
corpus_para_analize_da_palavra_alvo = ""
contador = 0
# Para cada arquivo dentro de uma pasta
for arquivo in os.listdir(pasta_corpus):
    if arquivo.endswith(".txt"):
        caminho_arquivo = os.path.join(pasta_corpus, arquivo)

        # Abre e lê o arquivo
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            texto = f.read().strip()  # Remove espaços extras

        # Tokeniza a sentença
        token_espaco = tokenize.WhitespaceTokenizer()
        corpus_token = token_espaco.tokenize(texto)


        # Se a sentença tiver a palavra alvo
        if palavra_alvo in corpus_token:
            contador +=1
            # Adciona na strin geral
            corpus_para_analize_da_palavra_alvo += " " + texto.lower()

print(contador)

# Cria o freqdist das sentenças selecionadas
corpus_da_palavra_alvo = string_to_freqdist(corpus_para_analize_da_palavra_alvo)


# Cria o freqdist da amostra geral da língua portuguesa
amostra_geral_lingua = itera_ou_abre_arquivos(caminho_corpus_geral)
amostra_geral_lingua = string_to_freqdist(amostra_geral_lingua)

# seleciona apenas as palavras acima do limiar do loglikelihood
Lista_mais_comuns_da_palvra_alvo = corpus_calibrado_log_likelihood(corpus_da_palavra_alvo, amostra_geral_lingua, 40)

# Cria a lista de mais comuns
Lista_mais_comuns_da_palvra_alvo.most_common(15)

 #corpus_freqdist = nltk.FreqDist(word.lower() for word in corpus_tokenizado)
# Out:
# 30
# Nº Caracteres corpora: pt.txt -
# 17034654
# [('elis', 32),
#  ('regina', 10),
#  ('ditadura', 8),
#  ('empresa', 6),
#  ('propaganda', 5),
#  ('imagem', 5),
#  ('apoiou', 4),
#  ('patrocinou', 3),
#  ('volkswagen', 3)]

# %%
# Sorteia x Comentários que contenham uma determinada palavra

import random, os

pasta_corpus = "corpus_comentarios_elis/"
palavra_alvo = "Elis"

lista_de_comentarios_selecionados = []

# Para cada arquivo dentro de uma pasta
for arquivo in os.listdir(pasta_corpus):
    # Verifica se o arquivo termina com txt
    if arquivo.endswith(".txt"):
        caminho_arquivo = os.path.join(pasta_corpus, arquivo)

        # Abre o arquivo e tranforma o texto em uma string
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            comentario = f.read().strip()  # Remove espaços extras

        if palavra_alvo.lower() in comentario.lower():
            lista_de_comentarios_selecionados.append(comentario)

# Sorteando 10 itens sem repetição
itens_sorteados = random.sample(lista_de_comentarios_selecionados, 5)

print(itens_sorteados)
# Out:
# ['Nem sou do tempo de Elis Regina e me emocionei com a propaganda, ficou perfeita', 'Horrível.\nacho uma falta de respeito com a imagem da Elis.\nPoderiam colocar um vídeo real dela cantando a Elis não é uma inteligência artificial nunca deve se comparar como tal\nmas nada contra Maria Rita So a minha opniao', 'Propaganda massa, bom ver a Elis, mas a música... nada a ver com o contexto😂', 'Fiquei ARREPIADA literalmente, que coisa mais linda, nunca vi propaganda mais bonita e mais bem produzida. Um estouro!! PARABÉNS, eterna Elis Regina.  🙌❤️', 'Muito bom. Consigo ver Elis com a filha adulta. Comerciais da Volkswagen sempre foram bons, mas esse, superou todos. 👏', 'a Elis Regina era contra a ditadura que vocês apoiaram ❤', 'A Elis do PS5 tá surreal. Kkkk', 'Parabéns por esse comercial emocionante! Voltei no tempo pra dentro do fusquinha do meu pai escutando Elis Regina nas fitas cassete dele que eu sempre desenrolava quando pegava hehehe. Me deu uma vontade imensa de ter uma "kombi" dessas :-)', '👏👏👏 Gostei da homenagem à cantora Elis Regina e à Volkswagen . \nClima de saudosismo e lembranças da infância. \nBem digno, sem apelação, sem lacração. \nPerfeito! \nParabéns, Volkswagen! \n👏👏👏', 'Minha irmã e minha família sabem o quanto essa música é a música da minha vida, o quanto eu amo Elis, esse comercial está para lá de espetacular. Meu pai morreu em 2019, com 54 anos, e eu herdei seu fusquinha... Vi minha vida nesse vídeo!']
